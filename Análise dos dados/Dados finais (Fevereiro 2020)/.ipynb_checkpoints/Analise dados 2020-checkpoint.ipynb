# %%
import pylab
pylab.rcParams['figure.figsize'] = (12.0, 12.0)


import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('DADOS_2020.csv', header=None)

# %% [markdown]
# #### Tratamento dos dados

# %%
dados = dados.iloc[:,0:10]

dias = []
horas = []
#print(dados[4][0])
for i in range(0, len(dados)):
    #Modelo: 2017-01-01 05:03 
    dias.append(("%d-%d-%d" %(dados[6][i], dados[5][i], 
                 dados[4][i])))
    horas.append(("%d-%d-%d %d:%d:%d" %(dados[6][i], dados[5][i], 
                 dados[4][i], dados[7][i], dados[8][i], dados[9][i])))
    
dados = dados.iloc[:, 0:4]
horario = pd.to_datetime(horas)
dados = dados.join(pd.DataFrame(horario), how='outer', rsuffix=' ')
dados.columns = ['Solução 1', 'Solução 2', 'Solução 3', 'Solução 4', 'Horario']
dados = dados.set_index('Horario')

# %%
def FiltraPositivo(coluna):
    for elemento in range(len(coluna)):
        print(coluna[elemento])
        if(coluna[elemento] > 0): 
            coluna[elemento] = - coluna[elemento]
            coluna[elemento]

# %%
def geraGrafico(nomeX, titulo, solucao, dadosmin, dadosmax, 
                limY_inf=0, limY_sup=2.5, minutos=10, cor='red'):
    solucao = solucao.iloc[range(dadosmin, dadosmax, minutos)] 
    plt.title(titulo, fontsize=14)
    plt.xlabel(nomeX, fontsize=14)
    plt.ylabel("Potential difference in Volts", fontsize=14)
    
    plt.ylim(limY_inf, limY_sup)
    plt.grid(True, linewidth=1)
    plt.gcf().autofmt_xdate()
    plt.plot(solucao, color=cor)

# %% [markdown]
# #### Filtrando os dados

# %%
solucao1 = dados.iloc[:, 0]
solucao1 = solucao1[solucao1 >= -1.1] 
FiltraPositivo(solucao1)

solucao2 = dados.iloc[:, 1]
solucao2 = solucao2[solucao2 >= -1.1] 

solucao3 = dados.iloc[:, 2]
solucao3 = solucao3[solucao3 >= -1.1] 

solucao4 = dados.iloc[:, 3]
solucao4 = solucao4[solucao4 >= -0.7] 


solucao1 = -0.9484 - solucao1
solucao2 = solucao2 + 0.2518
solucao3 = -0.9484 - solucao3
solucao4 = solucao4 + 0.2518

# %%
geraGrafico("Date", "Grafico", solucao1, 0, len(solucao1), 1, -1, 10, 'blue')

# %%
geraGrafico("Dados 1", "Grafico",dados['Solução 2'], 0, len(dados['Solução 2']), 0, -1.2, 10, 'red')

# %%
geraGrafico("Dados 1", "Grafico",dados['Solução 3'], 0, len(dados['Solução 3']), 0, dados['Solução 3'].min(), 10, 'green')

# %%
geraGrafico("Dados 1", "Grafico",dados['Solução 4'], 0, len(dados['Solução 4']), 0, dados['Solução 4'].min(), 10, 'yellow')

# %%
a = pd.Series(pd.Series(dias).drop_duplicates())
for i in a:
    print("Dia:", i)
# Out:
# Dia: 2019-10-17
# Dia: 2019-10-18
# Dia: 2019-10-19
# Dia: 2019-10-20
# Dia: 2019-10-21
# Dia: 2019-10-22
# Dia: 2019-10-23
# Dia: 2019-10-24
# Dia: 2019-10-25
# Dia: 2019-10-26
# Dia: 2019-10-27
# Dia: 2019-10-28
# Dia: 2019-10-29
# Dia: 2019-10-30
# Dia: 2019-10-31
